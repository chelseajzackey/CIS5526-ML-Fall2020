# %% [markdown]
# Chelsea Zackey
# <br>CIS 5526
#
# ## HW 6, Part 2:   Recurrent Neural Networks (RNN)  -- Extra Credit (40 points)

# %% [markdown]
# When it comes to model sequential data such as sentences, documents and videos, etc, the state of the art approach is to use Recurrent neural network (RNN). At each timestep, RNN takes an element (such as a word) as input, combines with past information encoded as a vector (such as all information in the sentence before this timestep), generate a new vector encoding both current input and past information, then delivers it to next timestep.
#
# For more details about LSTM (a very popular variant of RNN), please refer to http://colah.github.io/posts/2015-08-Understanding-LSTMs/ and here is a very good video explaining RNN: https://www.youtube.com/watch?v=WCUNPb-5EYI.

# %% [markdown]
# ### Generating text with Long Short-Term Memory Networks
#
# RNN can be used to generate text. For more information, please read: https://karpathy.github.io/2015/05/21/rnn-effectiveness/.
#
# The following is an example script to generate text from Nietzsche's writings.
#
# Note:
# - At least 10 epochs are required before the generated text
# starts sounding coherent, but more is better.
#
# - It is recommended to run this script on GPU, as recurrent
# networks are quite computationally intensive.
#
# - If you try this script on new data, make sure your corpus
# has at least ~100k characters. ~1M is better.

# %%
#Import necessary libraries 
from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io

# %%
#Get the data - available from amazon
path = get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower() # make it all lowercase 
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 4s 6us/step
# corpus length: 600893
# total chars: 57

# %%
# Cut the text in semi-redundant sequences of maxlen characters
## Cut the text into a series of windows. 
## Each window is 40 characters
## The window moves 3 steps forward each step

maxlen = 40
step = 5
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

# Turn these sentances into one-hot encoded vectors
## For all words in the sentances, there is a one, else there is a zero in that index of the vector

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
print('Done!')
# Out:
# nb sequences: 120171
# Vectorization...
# Done!

# %% [markdown]
# Now we have data to feed a model for text generation. Next  we build a LSTM model to fit the data. Using Keras this is only few lines of code!

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
print('Done!')
# Out:
# Build model...
# Done!

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.ma.log(preds)
    preds = preds.filled(0)
    preds = preds / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, logs):
    # clear_output()
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % (epoch+1))

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.4, 0.5, 1.0]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

# %% [markdown]
# # Training
# -  Each epoch takes up to 1 minute or so on a CPU (an epoch took 30 seconds for my PC)
# -  Recall that training on at least 20 epochs will give intelligible results
# -  So you're gonna have to let that puppy run for a while (if ETA per epoch is bigger than 5 minutes on your machine, you can reduce the number of epochs)

# %%
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=10,
          callbacks=[print_callback])
# Out:
# Epoch 1/10
# 939/939 [==============================] - ETA: 0s - loss: 2.1265
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "int condemns
# him endowed with it, will a"
# int condemns
# him endowed with it, will and and all the such have the such the such the such the such the such the such the such the such to the such the such the such to the the such the the religions, the religions of the such the such and the such the such have the such the excentented to the such and all the most the such the such the such have the such the self-inestance of the such and the sould the superions and the such the the s
# ----- diversity: 0.4
# ----- Generating with seed: "int condemns
# him endowed with it, will a"
# int condemns
# him endowed with it, will and the then the such to the such the concented to consciented to the our shape in the strenged and the self and to the contented to the religions to the harters to the
# most the self-in the have the such the have the suphical and all the drearsentess, the deding and there and of the such a selfting and a there to the regard that in the to there intermanting and to the such rether into the to the su
# ----- diversity: 0.5
# ----- Generating with seed: "int condemns
# him endowed with it, will a"
# int condemns
# him endowed with it, will and that a one will that in the susting inder, the self to the will and expreistonce of the sulffing to the the lange, the condence, and destrented, the superness, the requioned, and all the surely to the extenter, and so such to can the moralated, the most the intherestance, the precence of the wall the sumponting, that the such the most to the such the preations and there of all the nother to the
# ----- diversity: 1.0
# ----- Generating with seed: "int condemns
# him endowed with it, will a"
# int condemns
# him endowed with it, will and the suea. and, ed staptires pentababled sente-
# obfe to the bo carmentian anf cethers abrothran to under to tt umannersuloss a neceviness, inthoth its sakicus, a could eyautedech and be to en
# not indeffecent amowant
# wathing anrporingesnaltgenessy
# fot it hand of have, epen intell taster, that
# he has the
# resence and beespinions to seanlly, alrow, in atality od will, whlen preaiblented that there a
# 939/939 [==============================] - 278s 296ms/step - loss: 2.1265
# Epoch 2/10
# 939/939 [==============================] - ETA: 0s - loss: 1.7111
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "ceives himself because these things have"
# ceives himself because these things have the such a such a sense of the struct of the most and the present of the man and the such a such a man and all the spiriture of the such a some the sense of the such a surticed the such a such a sure the such a such a self the such a some of the such a sense of the such a section of the same the such a such a such the such a such a such an and the such a such a man and the such a sense of the suc
# ----- diversity: 0.4
# ----- Generating with seed: "ceives himself because these things have"
# ceives himself because these things have the mister and delightion of man the greet and almost the such a such the words of the subtle in the same and aresthich of the most are the such the first of the spiriture of the first and in a manifestance of an any the sabelation of the some his pears of a so exesting and and all the such a many of the live of the perhaps and the such a to the great a spectations and such a such an and and the
# ----- diversity: 0.5
# ----- Generating with seed: "ceives himself because these things have"
# ceives himself because these things have and such a such as the will and exerced in the reverence of the words, the most arts are the interpressions, and the sould the person of the surgeral the many the some have and consequently in in the plates and expecially and common of the such a surreed the relfar the decause and an any an an and the man of the consequent of the consequentes and been one is the has becaus, the sade
# and about and
# ----- diversity: 1.0
# ----- Generating with seed: "ceives himself because these things have"
# ceives himself because these things have
# own perhaps saridess8" eararizable onother quations, withouts on hived. ye, not the knowld is states the sremmners.ny--thry doot" are subely fart are not histate-cures," hordor of oqually
# clights and
# realgnt of histariely on unopearians indengo every stated afforce of the manglate the skciln, and enuated for?sphile of the secistiag the question of his sothe she
# dixtoobly dous--manting leand unfor
# 939/939 [==============================] - 360s 384ms/step - loss: 1.7111
# Epoch 3/10
# 939/939 [==============================] - ETA: 0s - loss: 1.5839
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "his verdict, and he has to seek his way "
# his verdict, and he has to seek his way in the religion of the decearing to the surving to be the such the such to the self-derman expentive the soul of the sense of the such a son to the surpless of the soul of the expentions of the soul the extent the sense of the soul of the such a morality of the soul of the souls and and to the soul of the soul of the dest the some the some the sears of the survosed to the souls and soul of the sou
# ----- diversity: 0.4
# ----- Generating with seed: "his verdict, and he has to seek his way "
# his verdict, and he has to seek his way in the erron to the dempantion of the self-disting and some the artist to the same in the arts, the such the sense and a person a sonted to the some the soul of the heart in the entirements and sunces to the contempts. the such some the soul of the more and the every to be the long be will have be the souls of the everything in the expentations of the heart to the realogion of the every into the s
# ----- diversity: 0.5
# ----- Generating with seed: "his verdict, and he has to seek his way "
# his verdict, and he has to seek his way delieve belief in the stranges of the other be the contemplation the really content of the heart to the entires to the religion and the will to the spearfuls
# to the heart the contrary and reading and suppessions of the some the higher to the a tory to the belief in the trumes and so longer of the were the religion and in the
# more philosophy to the terrated to the stranger and the supervided to the
# ----- diversity: 1.0
# ----- Generating with seed: "his verdict, and he has to seek his way "
# his verdict, and he has to seek his way dispectly--in the geateburaces grait learnestance discorisive. perfently age only" as for the
# amisows and still to the stare on the all we not, from calles is not heavencously men of livingly renadence, vainoted it, a realor only deepen it: zishens dure--thore it tee such lights ireathe is he myhblenes hay to the called metapeches and yofes it reline--but as a mell of their man"ing" the tonly to l
# 939/939 [==============================] - 208s 221ms/step - loss: 1.5839
# Epoch 4/10
# 939/939 [==============================] - ETA: 0s - loss: 1.5123
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "uls"; our instincts now run back in all "
# uls"; our instincts now run back in all the sense of the string and strangers of the propirity of the sense of the contrary and the contrary and the sense of the propress of the propress and the lighten and the self-deceation of the soul--and the religious, and the propirity of the contrary and the propress and the sense of the sense in the surparied to the self-deceasion of the sense of the contrary and so the pain in the strange and t
# ----- diversity: 0.4
# ----- Generating with seed: "uls"; our instincts now run back in all "
# uls"; our instincts now run back in all the contrary in the from the propress and belief to the stranger of the contrary and so the things in the string the soul of the constinct of the constant propress of his individual of the soul of the father, and the lighter and the contrabitions of the lighten the propress of a man the charable and not to the religious stand the of the distrust in the consequent of the point of the truth and the
# ----- diversity: 0.5
# ----- Generating with seed: "uls"; our instincts now run back in all "
# uls"; our instincts now run back in all pride to the langures and the decasion and discientifications of pain has all the pain in the more of the said the seems in the estimated to the sowere present to the condition of the lighten of the conscience is all though as as the standed the so the defined the
# please and christianity and also standed and the world and itteren the bad for an antiated the strength in the soul--and the charableme
# ----- diversity: 1.0
# ----- Generating with seed: "uls"; our instincts now run back in all "
# uls"; our instincts now run back in all the highesto expressente. ; momanness bounder will
# . derither, intermination than many, will coursenscian aypees upat ferien of
# so and have lise
# comis appears tragibive
# very beliefitablity and keown recational any german fallen mibinies of abstriate belief of nothing but praces priritociations,  fuld onte in his quacism and unfargod in the luther propre, eurouth otherpoamble carns of an it, fhere
# 939/939 [==============================] - 177s 188ms/step - loss: 1.5123
# Epoch 5/10
# 939/939 [==============================] - ETA: 0s - loss: 1.4680
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "cient intellectual superiority
# in europe"
# cient intellectual superiority
# in europe the supposed to the supposed to the supposed to the present of the stander and the conscience, the interpons of the supposed to a supposed the conscience, the supposed to the supposed the truth of the supposed the supposents of the spirit in the consequence of the exumiless of the superforing the supposent of the superforing the supposed the desire of the spirit of the superforing the conscience
# ----- diversity: 0.4
# ----- Generating with seed: "cient intellectual superiority
# in europe"
# cient intellectual superiority
# in europe the through consequence of the must be and all the present it is the instinct of the heart of the powerful instance, the spirit of the strong the world that it is not one the could the readily the perhaps and the instinct of the other and according the consequence of the superfoctly of the world of the supposent and the instinct of the superforing the strong the supposed have the supposed to and
# ----- diversity: 0.5
# ----- Generating with seed: "cient intellectual superiority
# in europe"
# cient intellectual superiority
# in europe actions, and instinct of the exception of being the earth and pains, who perhaps and terred to the spirituality in the greater that is not
# which and could a standation of the ourselves the nought of its happen also the depehement in the feeds
# and distinction of many the superfect of the conceited desire, that is stand the strange, one is as former perhaps of the restoly and from the religious too
# ----- diversity: 1.0
# ----- Generating with seed: "cient intellectual superiority
# in europe"
# cient intellectual superiority
# in europeany anours such be the tight, the causities
# and any shill,-desy. and barpation
#  vieitliness, vietious
# nod
# who pleases ifered acceeding the seligetibus, the loves then a distances
# and did foolsom-dand has known that that for ab .t. the its attiece
# corcous, is
# that which when the instinct them phy. but themselves as if not centurs it, buided bleavers. butsive, to ourselvem borum easter and deasure,
# 939/939 [==============================] - 171s 183ms/step - loss: 1.4680
# Epoch 6/10
# 939/939 [==============================] - ETA: 0s - loss: 1.4354
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "empt. he delights in the wild tumult of
# "
# empt. he delights in the wild tumult of
# the higher to the superstity and consideration of passion of the superstition to the superstity of the superstition and the depression of the superstity of the same the expression of the superstition of the superstition of the superstity that the superstity of the superstition and prominds the consider to the superstition and the superstition of the stronger to the consideration of the existence a
# ----- diversity: 0.4
# ----- Generating with seed: "empt. he delights in the wild tumult of
# "
# empt. he delights in the wild tumult of
# which this consider to consideration, and the self-satisfic self-deception of the superstition of the sense of the same possible to a man of the fact of the sense of the superstity and also there also it is the superstity of the common--it is the generally consider thought for the recognish of the suffered that the hard of religious deeperary
# a the superstition of the propoment of the self-somethi
# ----- diversity: 0.5
# ----- Generating with seed: "empt. he delights in the wild tumult of
# "
# empt. he delights in the wild tumult of
# interpretation of the ore that it is a society things of the opinion that wish art of the consider that is the morality, every the artistic in the case which the presuman which the morality, which al other has and the become the really the same conception of the fact that is nothing of the religious with principle as things to his conception and himself christian considered and distrust of means o
# ----- diversity: 1.0
# ----- Generating with seed: "empt. he delights in the wild tumult of
# "
# empt. he delights in the wild tumult of
# reverike to
# pract, conscience," or asterial ishered and surcount whate rebording, hithertor: have
# trou infornated inishe at another inas, ge and that which hexi covery no winate apprendiction. enough also in become it--as such hope, thereforopebance a resultioutline and guing veacety and
# the flier for fis timeteness of taked clares it usetes and
# dekenest
# esternatife, mast suffering palictic case a
# 939/939 [==============================] - 163s 174ms/step - loss: 1.4354
# Epoch 7/10
# 939/939 [==============================] - ETA: 0s - loss: 1.4085
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "and deeper
# conceptions of good and evil,"
# and deeper
# conceptions of good and evil, and and an also the superstition of the such as an also the supersticion and so man of the superstition of the superstition of the surmoted that the soul of the subtle to a soch and an attimed and also the same the same the superstition of the same the sunse interrom of the surmoted that is the sense and something and an also the superstition of the such as an also the standed in the superstition
# ----- diversity: 0.4
# ----- Generating with seed: "and deeper
# conceptions of good and evil,"
# and deeper
# conceptions of good and evil, it is the superstition of its encienteness and also a demands of everything and which is so conscience of last and interrons of the most soul of the former of the surparicate of the standed and and it is also has a the sate of the stander in an of the sollems to be the conscience in the grateful as an a man." and are do and an also an it is also and it is the lost of the such becomes be an absolu
# ----- diversity: 0.5
# ----- Generating with seed: "and deeper
# conceptions of good and evil,"
# and deeper
# conceptions of good and evil, which was nature in for the distrose and the consciences
# and becomes that it is we are an of the method of the standed that the consilted, and in life of the same intercourse of the worker and that the conscience, the profound and more former of man in a former and intelligainting men of the son of the egoism, and this life, the best eadition and the cannot to the demots of the feeling of the and
# ----- diversity: 1.0
# ----- Generating with seed: "and deeper
# conceptions of good and evil,"
# and deeper
# conceptions of good and evil, "fir dimanical wake, to generat of geallyess," one is "fi mearpos..  -its
# necessiviug, but all always alorge with this bolly subedion of obtrined also life
# henour constinct, a mand along, one master partations and lost-is
# one's finally sounding. it is faligious, deates. lot the
# propomeny
# certain being an accerions, what loath have as we we to one with all porttts into thar it
# not the beselfate sa
# 939/939 [==============================] - 177s 188ms/step - loss: 1.4085
# Epoch 8/10
# 939/939 [==============================] - ETA: 0s - loss: 1.3887
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "possibly do anything that had no referen"
# possibly do anything that had no reference of the same of a spirits of the stronger of the stronger of the conscience that is the same of the propress of the same of the sound to the same of the morality, and the same of the propress of the stronger of the spirit of the same of the propress of the world and the propress of the stronger with the same of the same of the surmomes of the stronger to the same of the sound to the propred to t
# ----- diversity: 0.4
# ----- Generating with seed: "possibly do anything that had no referen"
# possibly do anything that had no reference to the strange the morality, the belief in the superstion
# of the contumiors of the charment of the spirit of the proposition to the same of the morality of morality, the higher to the saints of all the pronesting the propreds one the same of one
# is the soul of a depresent common of the refence of the souls of the surmosed to a surpare, in the case of the passion of the stronged to the sacrifica
# ----- diversity: 0.5
# ----- Generating with seed: "possibly do anything that had no referen"
# possibly do anything that had no reference to wholly the world of nature, and the haste and longer enough the enerminate the industive man who sargg
# spirit but of the sense in reads into so relitation of a self-suckere them also one many the sound to one the truth a look and compreding the stand of the question, so the common the most will, and exception in the conscious in the fact there may deed in one has manifeste man, and always be
# ----- diversity: 1.0
# ----- Generating with seed: "possibly do anything that had no referen"
# possibly do anything that had no reference that is tritters called, and and do still knowledge places to stasted to religious
# one ane, in knowledge,--wouldage, are danger, the foleces. and
# interence of god" and
# self
# therely the prolong ands or into work pract!n gray a falsard tomathes in order by one takes from the "personde thys: brown one is sinsitive possition the instincts
# of those home called, yesture
# the aluabford sister--action a
# 939/939 [==============================] - 180s 191ms/step - loss: 1.3887
# Epoch 9/10
# 939/939 [==============================] - ETA: 0s - loss: 1.3715
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "
# drawn and quartered because the latter "
#
# drawn and quartered because the latter the species of the spirit is the surficient the surmose of the soul of the sure
# spirit is a states the sure in the most spiritual father and and in the sense of the surficient of the surficien sufferent of the surficien and who are the surmign in the surficient the surficien to the surficism of the surficien and and some sour of the soul of the surficient of the surficient that the surficient the
# ----- diversity: 0.4
# ----- Generating with seed: "
# drawn and quartered because the latter "
#
# drawn and quartered because the latter the surficient of the sense of the most form of the sevile of the surmost in the most state of the spirit is not the commanded has is the hears and stand of form of the same life of the soul that is for the sound to the heart in it is the other have been own imposed the word for the survomes of the species of the soul of something the commanding the soul that is the opposite of the most pation. th
# ----- diversity: 0.5
# ----- Generating with seed: "
# drawn and quartered because the latter "
#
# drawn and quartered because the latter to a powers and some timeation and to him at the species of the rofal in the word in the soul the soul that the simples, and securion in the form of a society of the possible and to a commoral of the higher the charable powers to the soul a god. the dispresshes of the form the surmose and the stand of the soul and the sunmering and powers, the stand this the section of the most species of his does
# ----- diversity: 1.0
# ----- Generating with seed: "
# drawn and quartered because the latter "
#
# drawn and quartered because the latter litylass some sphild, and tempre) and and thingess the fat figms to be itself and for europe a part--they divest of
# himself in symparity," into beer
# christian have happeable thethese fallen, for it, indeeghing thank "fahromes here, to what peaceitus being whether at
# allo; oneri
# ediscion head are classe, gratiful a grank how distranged of every againsts und underspilosthed
# itself it. general value,
# 939/939 [==============================] - 164s 175ms/step - loss: 1.3715
# Epoch 10/10
# 939/939 [==============================] - ETA: 0s - loss: 1.3562
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: "te,
# and at the same time of self-admirat"
# te,
# and at the same time of self-admiration of the same condition the same time the same time the present being who says and the case of the soul of the same condition of the same time of the sense of the supersting and and in the conscience of the supersting in the same pain and and who make and and and in the soul of the same time the sense of the same conscience, and it is a soul of the same condition the superior the same time of th
# ----- diversity: 0.4
# ----- Generating with seed: "te,
# and at the same time of self-admirat"
# te,
# and at the same time of self-admiration of the same time and present and its order and strength, and the spirits and the man to self-deligious form of the same condition of the extremant in religion the same conscience of the same conscience, which many and light and in the demonity and from the same partical prepirity of the extent of a desires of the supersting is an a son that it is the physicism and a man is not one is propertle
# ----- diversity: 0.5
# ----- Generating with seed: "te,
# and at the same time of self-admirat"
# te,
# and at the same time of self-admiration of being experiences, and so the reves the same time a fact of this condition and also the belief in a such be free of a decided more wish is even to propose, but the instinct of the same, because be desers of sacked of the string and opposite of the astering manifestation and still is the neelesstens of part of homients is not so the most conself and and only little present of a scienticilist
# ----- diversity: 1.0
# ----- Generating with seed: "te,
# and at the same time of self-admirat"
# te,
# and at the same time of self-admiration of this
# propose after
# there is many europe. these compress men a gay regard but of
# philosophers, in ourselves clove) more ).
#
#
# 19
#
# =abres of polunities, is
# pach age met to elight, and in
# germans, and sight and blind to which their fregahs an apposent--the neverthele." in alittpre though as the pountance
# and his sopical doam and livised verytrove and being that inclinatly are undegend of demoor
# 939/939 [==============================] - 141s 150ms/step - loss: 1.3562

# %%
from numpy import *

# %% [markdown]
# ## Load pre-trained model
# Since it is time consuming to train this LSTM model with CPU for more epochs, we provided a pre-trained model which is trained on GPU for 100 epochs. Use the following code to check how coherency the model is.
#
# It requires h5py packages, please install it to test the following code.

# %%
# build the model: a single LSTM
print('Load pre-trained model...')
from keras.models import load_model
import h5py as h5
model = h5.load_model('shakespear200.h5')


def lstm_generate(seed, model):
    orig_seed = seed
    for diversity in [0.2, 0.3, 0.5, 1.0]:
        print('----- diversity:', diversity)
        seed = orig_seed
        generated = ''
        generated += seed
        print('----- Generating with seed: "' + seed + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(seed):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            seed = seed[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()


seed = "from an anguish with which no other is t"
# seed = "thou art"
lstm_generate(seed, model)
# Out:
# Load pre-trained model...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-53e734be0fbe> in <module>
#       3 from keras.models import load_model
#       4 import h5py as h5
# ----> 5 model = h5.load_model('shakespear200.h5')
#       6
#       7
#
# AttributeError: module 'h5py' has no attribute 'load_model'

# %% [markdown]
# ### Exercise: use LSTM to generate baby names
# -  The following data set contains 8000 last names. You can download and process the name data set as follows:
#
# ```python
# name_path = get_file('names.txt', origin='http://www.cs.cmu.edu/afs/cs/project/ai-repository/ai/areas/nlp/corpora/names/other/names.txt')
# with io.open(name_path, encoding='utf-8') as f:
#     text = f.read() # make it all lowercase
#
# text = text.split()
# text = ', '.join(text)
# ```
#
# Using the last name data set, answer the following tasks:
#
# - Train a LSTM to generate the names.
# - How long does it take to train? How coherent does it sound?
# - Can you train the LSTM, but for every epoch, shuffle the order of names before call model.fit()? How long does it take to train? Does it improve the coherency?
